# %% [markdown]
# <a href="https://colab.research.google.com/github/mustafaCoskunAgu/scProfiterole/blob/main/scProfiterole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the repository
# !git clone https://github.com/TencentAILabHealthcare/scPROTEIN.git

# Change directory to the repository
# %cd scPROTEIN/
# Out:
# Cloning into 'scPROTEIN'...
# remote: Enumerating objects: 229, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 229 (delta 11), reused 35 (delta 10), pack-reused 190 (from 1)
# Receiving objects: 100% (229/229), 255.31 MiB | 11.88 MiB/s, done.
# Resolving deltas: 100% (90/90), done.
# Updating files: 100% (72/72), done.
# /content/scPROTEIN

# %% [markdown]
# **This step takes too much time, please be patient**

# %%
# 1. Install PyTorch with CUDA 11.3 support
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html

# 2. Install PyG dependencies built for CUDA 11.3
# We use the specific URL for torch-1.11.0+cu113
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-1.11.0+cu113.html
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-1.11.0+cu113.html
# !pip install torch-geometric==2.0.4

# 3. Install scprotein
# !pip install scprotein
# Out:
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.11.0+cu113 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0)
# ERROR: No matching distribution found for torch==1.11.0+cu113
# Looking in links: https://data.pyg.org/whl/torch-1.11.0+cu113.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.1.2-cp312-cp312-linux_x86_64.whl size=3869147 sha256=14b630e8d53dedc101f08497fc2efa67b297df07e7090959c8d93902e11d2786
#   Stored in directory: /root/.cache/pip/wheels/84/20/50/44800723f57cd798630e77b3ec83bc80bd26a1e3dc3a672ef5
# Successfully built torch-scatter
# ...
# Looking in links: https://data.pyg.org/whl/torch-1.11.0+cu113.html
# ...

# %%
# !python train_stage1.py
# Out:
# peptides nums in total: 9354
# cell nums: 1490
# epoch 0, loss_regression: 75.84718509763479
# epoch 1, loss_regression: 65.50995552539825
# epoch 2, loss_regression: 62.05565667152405
# epoch 3, loss_regression: 59.8156396150589
# epoch 4, loss_regression: 58.94392108917236
# epoch 5, loss_regression: 57.233144760131836
# epoch 6, loss_regression: 56.501667618751526
# epoch 7, loss_regression: 56.53274440765381
# epoch 8, loss_regression: 55.80962002277374
# epoch 9, loss_regression: 54.477335810661316
# epoch 10, loss_regression: 53.3858597278595
# epoch 11, loss_regression: 53.20724427700043
# epoch 12, loss_regression: 51.41012692451477
# epoch 13, loss_regression: 51.04990100860596
# epoch 14, loss_regression: 50.098618388175964
# epoch 15, loss_regression: 50.0485121011734
# epoch 16, loss_regression: 49.28773283958435
# epoch 17, loss_regression: 48.86736023426056
# epoch 18, loss_regression: 47.800806522369385
# epoch 19, loss_regression: 47.03051710128784
# ...

# %%
# Download the file from the raw GitHub URL and save it as model2.py
# !wget -O model2.py https://raw.githubusercontent.com/mustafaCoskunAgu/scProfiterole/main/model.py

# Verify the file is there
# !ls -l model2.py
# Out:
# --2026-02-05 14:54:11--  https://raw.githubusercontent.com/mustafaCoskunAgu/scProfiterole/main/model.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104464 (102K) [text/plain]
# Saving to: ‘model2.py’
#
# model2.py           100%[===================>] 102.02K  --.-KB/s    in 0.003s
#
# 2026-02-05 14:54:12 (37.9 MB/s) - ‘model2.py’ saved [104464/104464]
#
# -rw-r--r-- 1 root root 104464 Feb  5 14:54 model2.py

# %%
# Download MyTutorial2.py
# !wget https://raw.githubusercontent.com/mustafaCoskunAgu/scProfiterole/main/MyTutorial2.py

# Confirm the download
# !ls MyTutorial2.py
# Out:
# --2026-02-05 14:54:12--  https://raw.githubusercontent.com/mustafaCoskunAgu/scProfiterole/main/MyTutorial2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10928 (11K) [text/plain]
# Saving to: ‘MyTutorial2.py’
#
# MyTutorial2.py      100%[===================>]  10.67K  --.-KB/s    in 0s
#
# 2026-02-05 14:54:12 (134 MB/s) - ‘MyTutorial2.py’ saved [10928/10928]
#
# MyTutorial2.py

# %%
# Remove the existing utils.py if it exists
# !rm -f utils.py

# Download the new version from GitHub
# !wget https://raw.githubusercontent.com/mustafaCoskunAgu/scProfiterole/main/utils.py
# Out:
# --2026-02-05 14:54:13--  https://raw.githubusercontent.com/mustafaCoskunAgu/scProfiterole/main/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8893 (8.7K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   8.68K  --.-KB/s    in 0s
#
# 2026-02-05 14:54:13 (86.7 MB/s) - ‘utils.py’ saved [8893/8893]

# %% [markdown]
# If you have any problem in running the below code about peptide_uncertainty_estimation, please put peptide_uncertainty_estimation. before related code, e.g., from multi_task_heteroscedastic_regression_loss should be  peptide_uncertainty_estimation.from multi_task_heteroscedastic_regression_loss

# %%
# !python MyTutorial2.py
# Out:
# Kernel is  Heat_I
# [1.19557803e-10 1.60941714e-09 1.97911275e-08 2.21510885e-07
#  2.23489998e-06 2.00872885e-05 1.58469366e-04 1.07654973e-03
#  6.13930119e-03 2.83623328e-02 1.00680411e-01 2.52096579e-01
#  2.69257579e-01]
# Do not change coeffs
# [1.19557803e-10 1.60941714e-09 1.97911275e-08 2.21510885e-07
#  2.23489998e-06 2.00872885e-05 1.58469366e-04 1.07654973e-03
#  6.13930119e-03 2.83623328e-02 1.00680411e-01 2.52096579e-01
#  2.69257579e-01]
# Kernel is  Heat_I
# [1.19557803e-10 1.60941714e-09 1.97911275e-08 2.21510885e-07
#  2.23489998e-06 2.00872885e-05 1.58469366e-04 1.07654973e-03
#  6.13930119e-03 2.83623328e-02 1.00680411e-01 2.52096579e-01
#  2.69257579e-01]
# Do not change coeffs
# [1.19557803e-10 1.60941714e-09 1.97911275e-08 2.21510885e-07
#  2.23489998e-06 2.00872885e-05 1.58469366e-04 1.07654973e-03
#  6.13930119e-03 2.83623328e-02 1.00680411e-01 2.52096579e-01
#  2.69257579e-01]
# Kernel is  Heat_I
# ...
